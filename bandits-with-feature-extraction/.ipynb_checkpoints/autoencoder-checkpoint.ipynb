# %%
## widen the cell width
from IPython.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))
# Out:
# <style>.container { width:75% !important; }</style>

# %%
import os
import torch
import torchvision
import cv2
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import warnings
from collections import OrderedDict

warnings.filterwarnings("ignore", category=UserWarning)

# %%
# os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

device_count = torch.cuda.device_count()
for i in range(device_count):
    device_name = torch.cuda.get_device_name(i)
    print(f"GPU {i}: {device_name}")
# Out:
# GPU 0: NVIDIA GeForce RTX 3090
# GPU 1: NVIDIA GeForce RTX 3090

# %%
## load device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Current Device : {DEVICE}")

## create dataset save location
PATH = "./mnist/"
if os.path.exists(PATH):
    print(f"The directory '{PATH}' already exists.")
else:
    os.mkdir(PATH)
    print(f"The directory '{PATH}' successfully created.")
# Out:
# Current Device : cuda
# The directory './mnist/' already exists.

# %%
## hyperparameters
EPOCHS = 15
BATCH_SIZE = 100
LEARNING_RATE = 0.005
INPUT_SIZE = 28*28

# %%
## Data preparation
totensor = torchvision.transforms.ToTensor()

trainset = torchvision.datasets.MNIST(root=PATH, train=True, download=True, transform=totensor)
testset = torchvision.datasets.MNIST(root=PATH, train=False, download=True, transform=totensor)

if device_count == 1:
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
    testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=True)
else:
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, 
                                              shuffle=True, num_workers=device_count)
    testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE,
                                             shuffle=True, num_workers=device_count)

# %%
## show some samples
def plot_dataset(dataloader, grid_width, grid_height, figure_width, figure_height):
    images, labels = next(iter(dataloader))
    fig, ax = plt.subplots(grid_height, grid_width)
    fig.set_size_inches(figure_width, figure_height)
    for i in range(grid_height):
        for j in range(grid_width):
            img_idx = np.random.choice(np.arange(BATCH_SIZE), replace=False)
            image, label = images[img_idx], labels[img_idx]
            ax[i][j].axis('off')
            ax[i][j].set_title(label.item(), color='black')
            ax[i][j].imshow(image.squeeze(), cmap='gray')
        plt.subplots_adjust(hspace=0.25)
    plt.tight_layout()
    plt.show()

# %%
plot_dataset(trainloader, grid_width=10, grid_height=3, figure_width=12, figure_height=4)

# %% [markdown]
# # Naive AutoEncoder using 2 FC Layers

# %%
## Naive Autoencoder
class AutoEncoder(nn.Module):
    ## Two-FC-layer encoder and decoder
    def __init__(self, encoded_dim):
        super(AutoEncoder, self).__init__()
        
        self.input_size = 28 * 28
        self.hidden1 = 512
        self.hidden2 = encoded_dim
        
        self.fc1 = nn.Linear(self.input_size, self.hidden1)
        self.fc2 = nn.Linear(self.hidden1, self.hidden2)
        
        self.fc3 = nn.Linear(self.hidden2, self.hidden1)
        self.fc4 = nn.Linear(self.hidden1, self.input_size)

    def encode(self, x):
        x = x.view(-1, self.input_size)
        x = torch.sigmoid(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        return x
    
    def decode(self, x):
        x = torch.sigmoid(self.fc3(x))
        x = torch.sigmoid(self.fc4(x))
        return x
    
    def forward(self, x):
        encoded = self.encode(x)
        decoded = self.decode(encoded)
        return decoded

# %%
## loss functions and optimizer
LOSS_FUNCTIONS = ['BCE', 'MSE', 'MAE']
OPTIMIZERS = {
    'sgd': torch.optim.SGD, 
    'rmsprop': torch.optim.RMSprop, 
    'adagrad': torch.optim.Adagrad, 
    'adam': torch.optim.Adam, 
    'adamax': torch.optim.Adamax,
    'adadelta': torch.optim.Adadelta,
}

# %%
def train(epoch, model, loss_function, train_loader, optimizer, verbose=False):
    assert loss_function in LOSS_FUNCTIONS
    model.train()
    train_loss = 0
    batch_idx = 0
    for image, _ in train_loader:
        image = image.to(DEVICE)
        
        ## initialize the optimizer
        optimizer.zero_grad()
        
        ## decoded output
        decoded = model(image)
        
        ## compute loss for each batch
        if loss_function == "BCE":
            loss = F.binary_cross_entropy(decoded, image.view(-1, INPUT_SIZE))
        elif loss_function == "MSE":
            loss = F.mse_loss(decoded, image.view(-1, INPUT_SIZE))
        else:
            loss = F.l1_loss(decoded, image.view(-1, INPUT_SIZE))
        
        ## accumulate the total train loss during the epoch and backpropagation
        train_loss += loss.item()
        loss.backward()
        optimizer.step()
        
        ## Check training status
#         if batch_idx % 100 == 0:
#             print(f'Train Epoch: {epoch} [{batch_idx*len(image)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\t Loss: {loss.item()/len(image):.6f}')
        
        batch_idx += 1

    if verbose:
        print(f"Epoch: {epoch} Average training loss: {train_loss / len(train_loader.dataset):.6f}")
    
    return train_loss / len(train_loader.dataset)


def test(epoch, model, loss_function, test_loader, verbose=False):
    model.eval()
    test_loss = 0
    batch_idx = 0
    with torch.no_grad():
        for image, _ in test_loader:
            image = image.to(DEVICE)
            decoded = model(image)

            ## compute loss for each batch
            if loss_function == "BCE":
                loss = F.binary_cross_entropy(decoded, image.view(-1, INPUT_SIZE))
            else:
                loss = F.mse_loss(decoded, image.view(-1, INPUT_SIZE))
            
            test_loss += loss.item()
        
        if verbose:
            print(f"Epoch: {epoch} Average test loss: {test_loss / len(test_loader.dataset):.6f}")
    
    return test_loss / len(test_loader.dataset)

# %%
def run(model, loss_fn, encoded_dim, optim_name, verbose1=False, verbose2=True, save_model=False):
    optimizer = OPTIMIZERS[optim_name](model.parameters(), lr=LEARNING_RATE)   
    train_losses = np.zeros(EPOCHS)
    test_losses = np.zeros(EPOCHS)
    for epoch in tqdm(range(EPOCHS)):
        train_loss = train(epoch, model, loss_fn, trainloader, optimizer, verbose=verbose1)
        test_loss = test(epoch, model, loss_fn, testloader, verbose=verbose1)
        
        train_losses[epoch] = train_loss
        test_losses[epoch] = test_loss
        
    if verbose2:
        print(f"{loss_fn}\tEncoded dimension: {encoded_dim}\tAverage Training loss: {np.mean(train_losses):.6f}\tAverage Test loss: {np.mean(test_loss):.6f}")
        
    if save_model:
        saved_model = model.state_dict()
        fname = f"./saved_model_{loss_fn}_{encoded_dim}.pt"
        torch.save(saved_model, fname)
    return np.mean(train_losses), np.mean(test_losses)

# %%
# Loss function, Encoded dimension에 따른 loss 차이
encoded_dims = [16, 64, 144, 256]

bce_train_losses, bce_test_losses = dict(), dict()
for encoded_dim in encoded_dims:
    if device_count == 1:
        model = AutoEncoder(encoded_dim).to(DEVICE)
    else:
        device_ids = list(np.arange(device_count))
        model = nn.DataParallel(AutoEncoder(encoded_dim), device_ids=device_ids).to(DEVICE)

    print(model)
    train_loss, test_loss = run(model, "BCE", encoded_dim, "adam", verbose2=True, save_model=False)
    bce_train_losses[encoded_dim] = train_loss
    bce_test_losses[encoded_dim] = test_loss
    
mse_train_losses, mse_test_losses = dict(), dict()
for encoded_dim in encoded_dims:
    if device_count == 1:
        model = AutoEncoder(encoded_dim).to(DEVICE)
    else:
        device_ids = list(np.arange(device_count))
        model = nn.DataParallel(AutoEncoder(encoded_dim), device_ids=device_ids).to(DEVICE)

    print(model)
    train_loss, test_loss = run(model, "MSE", encoded_dim, "adam", verbose2=True, save_model=False)
    mse_train_losses[encoded_dim] = train_loss
    mse_test_losses[encoded_dim] = test_loss
    
mae_train_losses, mae_test_losses = dict(), dict()
for encoded_dim in encoded_dims:
    if device_count == 1:
        model = AutoEncoder(encoded_dim).to(DEVICE)
    else:
        device_ids = list(np.arange(device_count))
        model = nn.DataParallel(AutoEncoder(encoded_dim), device_ids=device_ids).to(DEVICE)

    print(model)
    train_loss, test_loss = run(model, "MAE", encoded_dim, "adam", verbose2=True, save_model=False)
    mae_train_losses[encoded_dim] = train_loss
    mae_test_losses[encoded_dim] = test_loss
# Out:
# DataParallel(
#   (module): AutoEncoder(
#     (fc1): Linear(in_features=784, out_features=512, bias=True)
#     (fc2): Linear(in_features=512, out_features=16, bias=True)
#     (fc3): Linear(in_features=16, out_features=512, bias=True)
#     (fc4): Linear(in_features=512, out_features=784, bias=True)
#   )
# )
#   0%|          | 0/15 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 13
#      10     model = nn.DataParallel(AutoEncoder(encoded_dim), device_ids=device_ids).to(DEVICE)
#      12 print(model)
# ---> 13 train_loss, test_loss = run(model, "BCE", encoded_dim, "adam", verbose2=True, save_model=False)
#      14 bce_train_losses[encoded_dim] = train_loss
#      15 bce_test_losses[encoded_dim] = test_loss
#
# Cell In[12], line 6, in run(model, loss_fn, encoded_dim, optim_name, verbose1, verbose2, save_model)
#       4 test_losses = np.zeros(EPOCHS)
#       5 for epoch in tqdm(range(EPOCHS)):
# ----> 6     train_loss = train(epoch, model, loss_fn, trainloader, optimizer, verbose=verbose1)
#       7     test_loss = test(epoch, model, loss_fn, testloader, verbose=verbose1)
#       9     train_losses[epoch] = train_loss
#
# Cell In[11], line 13, in train(epoch, model, loss_function, train_loader, optimizer, verbose)
#      10 optimizer.zero_grad()
#      12 ## decoded output
# ---> 13 decoded = model(image)
#      15 ## compute loss for each batch
#      16 if loss_function == "BCE":
#
# File ~/anaconda3/envs/main/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/main/lib/python3.10/site-packages/torch/nn/parallel/data_parallel.py:170, in DataParallel.forward(self, *inputs, **kwargs)
#     168 if len(self.device_ids) == 1:
#     169     return self.module(*inputs[0], **kwargs[0])
# --> 170 replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     171 outputs = self.parallel_apply(replicas, inputs, kwargs)
#     172 return self.gather(outputs, self.output_device)
#
# File ~/anaconda3/envs/main/lib/python3.10/site-packages/torch/nn/parallel/data_parallel.py:175, in DataParallel.replicate(self, module, device_ids)
#     174 def replicate(self, module, device_ids):
# --> 175     return replicate(module, device_ids, not torch.is_grad_enabled())
#
# File ~/anaconda3/envs/main/lib/python3.10/site-packages/torch/nn/parallel/replicate.py:91, in replicate(network, devices, detach)
#      89 params = list(network.parameters())
#      90 param_indices = {param: idx for idx, param in enumerate(params)}
# ---> 91 param_copies = _broadcast_coalesced_reshape(params, devices, detach)
#      93 buffers = list(network.buffers())
#      94 buffers_rg = []
#
# File ~/anaconda3/envs/main/lib/python3.10/site-packages/torch/nn/parallel/replicate.py:65, in _broadcast_coalesced_reshape(tensors, devices, detach)
#      64 def _broadcast_coalesced_reshape(tensors, devices, detach=False):
# ---> 65     from ._functions import Broadcast
#      66     if detach:
#      67         return comm.broadcast_coalesced(tensors, devices)
#
# File <frozen importlib._bootstrap>:408, in parent(self)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(16, 4))

plt.subplot(131)
plt.plot(encoded_dims, bce_train_losses.values(), label=f"Training loss", marker='o')
plt.plot(encoded_dims, bce_test_losses.values(), label=f"Test loss", marker='o')
plt.grid(True)
plt.legend()
plt.xlabel("Encoded Dimension")
plt.ylabel("Training/Test Loss")
plt.xticks(encoded_dims)
plt.title("Cross Entropy Loss")

plt.subplot(132)
plt.plot(encoded_dims, mse_train_losses.values(), label=f"Training loss", marker='o')
plt.plot(encoded_dims, mse_test_losses.values(), label=f"Test loss", marker='o')
plt.grid(True)
plt.legend()
plt.xlabel("Encoded Dimension")
plt.ylabel("Training/Test Loss")
plt.xticks(encoded_dims)
plt.title("Mean Squared Error")

plt.subplot(133)
plt.plot(encoded_dims, mae_train_losses.values(), label=f"Training loss", marker='o')
plt.plot(encoded_dims, mae_test_losses.values(), label=f"Test loss", marker='o')
plt.grid(True)
plt.legend()
plt.xlabel("Encoded Dimension")
plt.ylabel("Training/Test Loss")
plt.xticks(encoded_dims)
plt.title("Mean Absolute Error")

plt.tight_layout()
plt.show()

# %%
# Final training
encoded_dim = 12*12
for loss_fn in LOSS_FUNCTIONS:
    if device_count == 1:
        model = AutoEncoder(encoded_dim).to(DEVICE)
    else:
        device_ids = list(np.arange(device_count))
        model = nn.DataParallel(AutoEncoder(encoded_dim), device_ids=device_ids).to(DEVICE)

    print(model)
    train_loss, test_loss = run(model, loss_fn, encoded_dim, "adam", verbose2=True, save_model=True)
# Out:
# DataParallel(
#   (module): AutoEncoder(
#     (fc1): Linear(in_features=784, out_features=512, bias=True)
#     (fc2): Linear(in_features=512, out_features=144, bias=True)
#     (fc3): Linear(in_features=144, out_features=512, bias=True)
#     (fc4): Linear(in_features=512, out_features=784, bias=True)
#   )
# )
#   0%|          | 0/15 [00:00<?, ?it/s]
# BCE	Encoded dimension: 144	Average Training loss: 0.000948	Average Test loss: 0.000777
# DataParallel(
#   (module): AutoEncoder(
#     (fc1): Linear(in_features=784, out_features=512, bias=True)
#     (fc2): Linear(in_features=512, out_features=144, bias=True)
#     (fc3): Linear(in_features=144, out_features=512, bias=True)
#     (fc4): Linear(in_features=512, out_features=784, bias=True)
#   )
# )
#   0%|          | 0/15 [00:00<?, ?it/s]
# MSE	Encoded dimension: 144	Average Training loss: 0.000091	Average Test loss: 0.000039
# DataParallel(
#   (module): AutoEncoder(
#     (fc1): Linear(in_features=784, out_features=512, bias=True)
#     (fc2): Linear(in_features=512, out_features=144, bias=True)
#     (fc3): Linear(in_features=144, out_features=512, bias=True)
#     (fc4): Linear(in_features=512, out_features=784, bias=True)
#   )
# )
#   0%|          | 0/15 [00:00<?, ?it/s]
# MAE	Encoded dimension: 144	Average Training loss: 0.000489	Average Test loss: 0.000137

# %%
## Comparison between the ground truth and re-constructed image
def model_comparison(model, loss_fn, encoded_dim, indices, dataloader, grid_width, grid_height, figure_width, figure_height, view_encoded=False):
    images, labels = next(iter(dataloader))
    view_size = int(np.sqrt(encoded_dim))
    
    ## show ground truth
    print("Ground Truth")
    fig, ax = plt.subplots(grid_height, grid_width)
    fig.set_size_inches(figure_width, figure_height)
    for i in range(grid_height):
        for j in range(grid_width):
            img_idx = indices[i*grid_width + j]
            image, label = images[img_idx], labels[img_idx]
            ax[i][j].axis('off')
            ax[i][j].set_title(label.item(), color='black')
            ax[i][j].imshow(image.squeeze(), cmap='gray')
        plt.subplots_adjust(hspace=0.25)
    plt.tight_layout()
    plt.show()
    
    ## load the trained model
    checkpoint = torch.load(f'saved_model_{loss_fn}_{encoded_dim}.pt')
    state_dict = OrderedDict()
    for key, value in checkpoint.items():
        key = key.replace('module.', '')
        state_dict[key] = value
    model.load_state_dict(state_dict)
    model.eval()
    
    if view_encoded:
        ## show the encoded images
        print("Encoded")
        fig, ax = plt.subplots(grid_height, grid_width)
        fig.set_size_inches(figure_width, figure_height)
        for i in range(grid_height):
            for j in range(grid_width):
                img_idx = indices[i*grid_width + j]
                image, label = images[img_idx], labels[img_idx]
                encoded = model.encode(image).detach().numpy()

                ax[i][j].axis('off')
                ax[i][j].set_title(label.item(), color='black')
                ax[i][j].imshow(encoded.reshape(view_size, view_size), cmap='gray')
            plt.subplots_adjust(hspace=0.25)
        plt.tight_layout()
        plt.show()        
    
    
    ## show the re-constructed images
    print("Reconstructed")
    fig, ax = plt.subplots(grid_height, grid_width)
    fig.set_size_inches(figure_width, figure_height)
    for i in range(grid_height):
        for j in range(grid_width):
            img_idx = indices[i*grid_width + j]
            image, label = images[img_idx], labels[img_idx]
            decoded = model(image).detach().numpy()

            ax[i][j].axis('off')
            ax[i][j].set_title(label.item(), color='black')
            ax[i][j].imshow(decoded.reshape(28, 28), cmap='gray')
        plt.subplots_adjust(hspace=0.25)
    plt.tight_layout()
    plt.show()

# %%
grid_width, grid_height = 10, 3
figure_width, figure_height = 12, 4
indices = np.random.choice(np.arange(BATCH_SIZE), replace=False, size=grid_height*grid_width)
sampleloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, 
                                           shuffle=False, num_workers=device_count)

for loss_fn in LOSS_FUNCTIONS:
    print(loss_fn)
    model = AutoEncoder(encoded_dim)
    model_comparison(model, loss_fn, encoded_dim, indices, sampleloader, grid_width, grid_height, figure_width, figure_height, view_encoded=True)
# Out:
# BCE
# Ground Truth
# Encoded
# Reconstructed
# MSE
# Ground Truth
# Encoded
# Reconstructed
# MAE
# Ground Truth
# Encoded
# Reconstructed

# %% [markdown]
# # AutoEncoder using simple CNN

# %%
## Naive Autoencoder
class CNNAE(nn.Module):
    ## Three-CNN-layer encoder and decoder
    def __init__(self):
        super(CNNAE, self).__init__()
        
        self.input_size = 28 * 28
        self.hidden1 = 256
        self.hidden2 = 256
        self.hidden3 = 144
        
        ## Encoder layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=self.hidden1, kernel_size=3, padding='same'),
            nn.Sigmoid()
        )
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=self.hidden1, out_channels=self.hidden2, kernel_size=3, padding='same'),
            nn.Sigmoid()
        )
        
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=self.hidden2, out_channels=self.hidden3, kernel_size=3, padding='same'),
            nn.Sigmoid()
        )
                
        ## Decoder Layer
        self.convt1 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=self.hidden3, out_channels=self.hidden2, kernel_size=3, padding=1),
            nn.Sigmoid()
        )
        
        self.convt2 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=self.hidden2, out_channels=self.hidden1, kernel_size=3, padding=1),
            nn.Sigmoid()
        )
        
        self.convt3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=self.hidden1, out_channels=1, kernel_size=3, padding=1),
            nn.Sigmoid()
        )

    def encode(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        return x
    
    def decode(self, x):
        x = self.convt1(x)
        x = self.convt2(x)
        x = self.convt3(x)
        return x
    
    def forward(self, x):
        encoded = self.encode(x)
        decoded = self.decode(encoded)
        return decoded

# %%
def train(epoch, model, loss_function, train_loader, optimizer, verbose=False):
    assert loss_function in LOSS_FUNCTIONS
    model.train()
    train_loss = 0
    batch_idx = 0
    for image, _ in train_loader:
        image = image.to(DEVICE)
        
        ## initialize the optimizer
        optimizer.zero_grad()
        
        ## decoded output
        decoded = model(image)
        
        ## compute loss for each batch
        if loss_function == "BCE":
            criterion = nn.CrossEntropyLoss()
        elif loss_function == "MSE":
            criterion = nn.MSELoss()
        else:
            criterion = nn.L1Loss()
        
        loss = criterion(decoded, image.squeeze())
        ## accumulate the total train loss during the epoch and backpropagation
        train_loss += loss.item()
        loss.backward()
        optimizer.step()
        
        ## Check training status
#         if batch_idx % 100 == 0:
#             print(f'Train Epoch: {epoch} [{batch_idx*len(image)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\t Loss: {loss.item()/len(image):.6f}')
        
        batch_idx += 1

    if verbose:
        print(f"Epoch: {epoch} Average training loss: {train_loss / len(train_loader.dataset):.6f}")
    
    return train_loss / len(train_loader.dataset)


def test(epoch, model, loss_function, test_loader, verbose=False):
    model.eval()
    test_loss = 0
    batch_idx = 0
    with torch.no_grad():
        for image, _ in test_loader:
            image = image.to(DEVICE)
            decoded = model(image)

            ## compute loss for each batch
            if loss_function == "BCE":
                criterion = nn.CrossEntropyLoss()
            elif loss_function == "MSE":
                criterion = nn.MSELoss()
            else:
                criterion = nn.L1Loss()

            loss = criterion(decoded, image.squeeze())
            
            test_loss += loss.item()
        
        if verbose:
            print(f"Epoch: {epoch} Average test loss: {test_loss / len(test_loader.dataset):.6f}")
    
    return test_loss / len(test_loader.dataset)



def run(model, model_name, loss_fn, optim_name, lr=None, verbose1=False, verbose2=True, save_model=False):
    if not lr:
        lr = LEARNING_RATE
    optimizer = OPTIMIZERS[optim_name](model.parameters(), lr=lr)
    train_losses = np.zeros(EPOCHS)
    test_losses = np.zeros(EPOCHS)
    for epoch in tqdm(range(EPOCHS)):
        train_loss = train(epoch, model, loss_fn, trainloader, optimizer, verbose=verbose1)
        test_loss = test(epoch, model, loss_fn, testloader, verbose=verbose1)
        
        train_losses[epoch] = train_loss
        test_losses[epoch] = test_loss
        
    if verbose2:
        print(f"{loss_fn}\tAverage Training loss: {np.mean(train_losses):.6f}\tAverage Test loss: {np.mean(test_loss):.6f}")
        
    if save_model:
        saved_model = model.state_dict()
        fname = f"./saved_model_{loss_fn}_{model_name}.pt"
        torch.save(saved_model, fname)
    return np.mean(train_losses), np.mean(test_losses)

# %%
if device_count == 1:
    model = CNNAE().to(DEVICE)
else:
    device_ids = list(np.arange(device_count))
    model = nn.DataParallel(CNNAE(), device_ids=device_ids).to(DEVICE)

model_name = CNNAE().__class__.__name__    
print(model)
train_loss, test_loss = run(model, model_name, "MSE", "adam", lr=3e-4, verbose1=True, verbose2=True, save_model=True)
# Out:
# DataParallel(
#   (module): CNNAE(
#     (conv1): Sequential(
#       (0): Conv2d(1, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): Sigmoid()
#     )
#     (conv2): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): Sigmoid()
#     )
#     (conv3): Sequential(
#       (0): Conv2d(256, 144, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): Sigmoid()
#     )
#     (convt1): Sequential(
#       (0): ConvTranspose2d(144, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Sigmoid()
#     )
#     (convt2): Sequential(
#       (0): ConvTranspose2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Sigmoid()
#     )
#     (convt3): Sequential(
#       (0): ConvTranspose2d(256, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Sigmoid()
#     )
#   )
# )
#   0%|          | 0/15 [00:00<?, ?it/s]
# Epoch: 0 Average training loss: 0.001130
# Epoch: 0 Average test loss: 0.001140
# Epoch: 1 Average training loss: 0.001120
# Epoch: 1 Average test loss: 0.001140
# Epoch: 2 Average training loss: 0.001120
# Epoch: 2 Average test loss: 0.001140
# Epoch: 3 Average training loss: 0.001120
# Epoch: 3 Average test loss: 0.001140
# Epoch: 4 Average training loss: 0.001120
# Epoch: 4 Average test loss: 0.001140
# Epoch: 5 Average training loss: 0.001120
# Epoch: 5 Average test loss: 0.001140
# Epoch: 6 Average training loss: 0.001120
# Epoch: 6 Average test loss: 0.001140
# Epoch: 7 Average training loss: 0.001120
# Epoch: 7 Average test loss: 0.001140
# Epoch: 8 Average training loss: 0.001120
# Epoch: 8 Average test loss: 0.001140
# Epoch: 9 Average training loss: 0.001120
# Epoch: 9 Average test loss: 0.001140
# Epoch: 10 Average training loss: 0.001120
# Epoch: 10 Average test loss: 0.001140
# Epoch: 11 Average training loss: 0.001120
# Epoch: 11 Average test loss: 0.001140
# Epoch: 12 Average training loss: 0.001120
# Epoch: 12 Average test loss: 0.001140
# Epoch: 13 Average training loss: 0.001120
# Epoch: 13 Average test loss: 0.001140
# Epoch: 14 Average training loss: 0.001120
# Epoch: 14 Average test loss: 0.001140
# MSE	Average Training loss: 0.001121	Average Test loss: 0.001140

# %%
train_loss, test_loss = run(model, model_name, "MAE", "adam", lr=3e-4, verbose1=True, verbose2=True, save_model=True)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# Epoch: 0 Average training loss: 0.001307
# Epoch: 0 Average test loss: 0.001325
# Epoch: 1 Average training loss: 0.001307
# Epoch: 1 Average test loss: 0.001325
# Epoch: 2 Average training loss: 0.001307
# Epoch: 2 Average test loss: 0.001325
# Epoch: 3 Average training loss: 0.001307
# Epoch: 3 Average test loss: 0.001325
# Epoch: 4 Average training loss: 0.001307
# Epoch: 4 Average test loss: 0.001325
# Epoch: 5 Average training loss: 0.001307
# Epoch: 5 Average test loss: 0.001325
# Epoch: 6 Average training loss: 0.001307
# Epoch: 6 Average test loss: 0.001325
# Epoch: 7 Average training loss: 0.001307
# Epoch: 7 Average test loss: 0.001325
# Epoch: 8 Average training loss: 0.001307
# Epoch: 8 Average test loss: 0.001325
# Epoch: 9 Average training loss: 0.001307
# Epoch: 9 Average test loss: 0.001325
# Epoch: 10 Average training loss: 0.001307
# Epoch: 10 Average test loss: 0.001325
# Epoch: 11 Average training loss: 0.001307
# Epoch: 11 Average test loss: 0.001325
# Epoch: 12 Average training loss: 0.001307
# Epoch: 12 Average test loss: 0.001325
# Epoch: 13 Average training loss: 0.001307
# Epoch: 13 Average test loss: 0.001325
# Epoch: 14 Average training loss: 0.001307
# Epoch: 14 Average test loss: 0.001325
# MAE	Average Training loss: 0.001307	Average Test loss: 0.001325

# %%
grid_width, grid_height = 10, 3
figure_width, figure_height = 12, 4
indices = np.random.choice(np.arange(BATCH_SIZE), replace=False, size=grid_height*grid_width)
sampleloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, 
                                           shuffle=False, num_workers=device_count)

# %%
images, labels = next(iter(testloader))
view_size = int(np.sqrt(encoded_dim))

## show ground truth
print("Ground Truth")
fig, ax = plt.subplots(grid_height, grid_width)
fig.set_size_inches(figure_width, figure_height)
for i in range(grid_height):
    for j in range(grid_width):
        img_idx = indices[i*grid_width + j]
        image, label = images[img_idx], labels[img_idx]
        ax[i][j].axis('off')
        ax[i][j].set_title(label.item(), color='black')
        ax[i][j].imshow(image.squeeze(), cmap='gray')
    plt.subplots_adjust(hspace=0.25)
plt.tight_layout()
plt.show()
# Out:
# Ground Truth

# %%
## load the trained model
model = CNNAE()
checkpoint = torch.load(f'saved_model_MSE_CNNAE.pt')
state_dict = OrderedDict()
for key, value in checkpoint.items():
    key = key.replace('module.', '')
    state_dict[key] = value
model.load_state_dict(state_dict)
model.eval()
# Out:
# CNNAE(
#   (conv1): Sequential(
#     (0): Conv2d(1, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): Sigmoid()
#   )
#   (conv2): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): Sigmoid()
#   )
#   (conv3): Sequential(
#     (0): Conv2d(256, 144, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): Sigmoid()
#   )
#   (convt1): Sequential(
#     (0): ConvTranspose2d(144, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Sigmoid()
#   )
#   (convt2): Sequential(
#     (0): ConvTranspose2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Sigmoid()
#   )
#   (convt3): Sequential(
#     (0): ConvTranspose2d(256, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Sigmoid()
#   )
# )

# %%
## show the re-constructed images
print("Reconstructed")
fig, ax = plt.subplots(grid_height, grid_width)
fig.set_size_inches(figure_width, figure_height)
for i in range(grid_height):
    for j in range(grid_width):
        img_idx = indices[i*grid_width + j]
        image, label = images[img_idx], labels[img_idx]
        decoded = model(image).detach().numpy()

        ax[i][j].axis('off')
        ax[i][j].set_title(label.item(), color='black')
        ax[i][j].imshow(decoded.reshape(28, 28), cmap='gray')
    plt.subplots_adjust(hspace=0.25)
plt.tight_layout()
plt.show()
# Out:
# Reconstructed
