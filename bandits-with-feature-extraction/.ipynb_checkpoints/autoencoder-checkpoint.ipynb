# %%
import os
import torch
import torchvision
import cv2
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %%
# !nvidia-smi -L | wc -l
# Out:
# 1

# %%
## load device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Current Device : {DEVICE}")

## create dataset save location
PATH = "./mnist/"
if os.path.exists(PATH):
    print(f"The directory '{PATH}' already exists.")
else:
    os.mkdir(PATH)
    print(f"The directory '{PATH}' successfully created.")
# Out:
# Current Device : cuda
# The directory './mnist/' already exists.

# %%
EPOCHS = 100
BATCH_SIZE = 128

# %%
## Data preparation
totensor = torchvision.transforms.ToTensor()

trainset = torchvision.datasets.MNIST(root=PATH, train=True, download=True, transform=totensor)
testset = torchvision.datasets.MNIST(root=PATH, train=False, download=True, transform=totensor)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=True)

# %%
## show some samples
def plot_dataset(dataloader, grid_width, grid_height, figure_width, figure_height):
    images, labels = next(iter(dataloader))
    fig, ax = plt.subplots(grid_height, grid_width)
    fig.set_size_inches(figure_width, figure_height)
    for i in range(grid_height):
        for j in range(grid_width):
            img_idx = np.random.choice(np.arange(BATCH_SIZE), replace=False)
            image, label = images[img_idx], labels[img_idx]
            ax[i][j].axis('off')
            ax[i][j].set_title(label.item(), color='black')
            ax[i][j].imshow(image.squeeze(), cmap='gray')
        plt.subplots_adjust(hspace=0.25)
    plt.tight_layout()
    plt.show()

# %%
plot_dataset(trainloader, grid_width=10, grid_height=3, figure_width=12, figure_height=4)

# %%
## Naive Autoencoder
class AutoEncoder(nn.Module):
    ## Two-FC-layer encoder and decoder
    def __init__(self, input_size, hidden1, hidden2):
        super(AutoEncoder, self).__init__()
        
        self.fc1 = nn.Linear(input_size, hidden1)
        self.fc2 = nn.Linear(hidden1, hidden2)
        
        self.fc3 = nn.Linear(hidden2, hidden1)
        self.fc4 = nn.Linear(hidden1, input_size)

    def plotting(dataloader, grid_width, grid_height, figure_width, figure_height):
        batch_size = dataloder.shape[0]
        fig, ax = plt.subplots(grid_height, grid_width)
        fig.set_size_inches(figure_width, figure_height)
        for i in range(grid_height):
            for j in range(grid_width):
                img_idx = np.random.choice(np.arange(batch_size), replace=False)
                image = dataloader[img_idx]
                ax[i][j].axis('off')
                ax[i][j].imshow(image.squeeze(), cmap='gray')
            plt.subplots_adjust(hspace=0.25)
        plt.tight_layout()
        plt.show()

    def encode(self, x, width, height):
        x = F.sigmoid(self.fc1(x))
        x = F.sigmoid(self.fc2(x))
        return x
    
    def decode(self, x):
        x = F.sigmoid(self.fc3(x))
        x = F.sigmoid(self.fc4(x))
        return x
    
    def forward(self, x, verbose=False):
        encoded = self.encode(torch.flatten(x))
        if verbose:
            view = x.view(-1, 1, width, height)
            plotting(view, grid_width=10, grid_height=2, figure_width=12, figure_height=3)
        decoded = decode(encoded)
        return decoded

# %%
## loss functions
loss_functions = ['BCE', 'MSE']

# %%
def train
