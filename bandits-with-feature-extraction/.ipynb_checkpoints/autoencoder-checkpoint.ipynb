# %%
## widen the cell width
from IPython.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))
# Out:
# <style>.container { width:75% !important; }</style>

# %%
import os
import torch
import torchvision
import cv2
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import warnings
from collections import OrderedDict

warnings.filterwarnings("ignore", category=UserWarning)

# %%
# os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

device_count = torch.cuda.device_count()
for i in range(device_count):
    device_name = torch.cuda.get_device_name(i)
    print(f"GPU {i}: {device_name}")
# Out:
# GPU 0: NVIDIA GeForce RTX 3090

# %%
## load device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Current Device : {DEVICE}")

## create dataset save location
PATH = "./mnist/"
if os.path.exists(PATH):
    print(f"The directory '{PATH}' already exists.")
else:
    os.mkdir(PATH)
    print(f"The directory '{PATH}' successfully created.")
# Out:
# Current Device : cuda
# The directory './mnist/' already exists.

# %%
## hyperparameters
EPOCHS = 20
BATCH_SIZE = 128
LEARNING_RATE = 0.001
INPUT_SIZE = 28*28

# %%
## Data preparation
totensor = torchvision.transforms.ToTensor()

trainset = torchvision.datasets.MNIST(root=PATH, train=True, download=True, transform=totensor)
testset = torchvision.datasets.MNIST(root=PATH, train=False, download=True, transform=totensor)

if device_count == 1:
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
    testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=True)
else:
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, 
                                              shuffle=True, num_workers=device_count)
    testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE,
                                             shuffle=True, num_workers=device_count)

# %%
## show some samples
def plot_dataset(dataloader, grid_width, grid_height, figure_width, figure_height):
    images, labels = next(iter(dataloader))
    fig, ax = plt.subplots(grid_height, grid_width)
    fig.set_size_inches(figure_width, figure_height)
    for i in range(grid_height):
        for j in range(grid_width):
            img_idx = np.random.choice(np.arange(BATCH_SIZE), replace=False)
            image, label = images[img_idx], labels[img_idx]
            ax[i][j].axis('off')
            ax[i][j].set_title(label.item(), color='black')
            ax[i][j].imshow(image.squeeze(), cmap='gray')
        plt.subplots_adjust(hspace=0.25)
    plt.tight_layout()
    plt.show()

# %%
plot_dataset(trainloader, grid_width=10, grid_height=3, figure_width=12, figure_height=4)

# %%
## Naive Autoencoder
class AutoEncoder(nn.Module):
    ## Two-FC-layer encoder and decoder
    def __init__(self, encoded_dim):
        super(AutoEncoder, self).__init__()
        
        self.input_size = 28 * 28
        self.hidden1 = 512
        self.hidden2 = encoded_dim
        
        self.fc1 = nn.Linear(self.input_size, self.hidden1)
        self.fc2 = nn.Linear(self.hidden1, self.hidden2)
        
        self.fc3 = nn.Linear(self.hidden2, self.hidden1)
        self.fc4 = nn.Linear(self.hidden1, self.input_size)

    def encode(self, x):
        x = x.view(-1, self.input_size)
        x = torch.sigmoid(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        return x
    
    def decode(self, x):
        x = torch.sigmoid(self.fc3(x))
        x = torch.sigmoid(self.fc4(x))
        return x
    
    def forward(self, x):
        encoded = self.encode(x)
        decoded = self.decode(encoded)
        return decoded

# %%
## loss functions and optimizer
LOSS_FUNCTIONS = ['BCE', 'MSE', 'MAE']
OPTIMIZERS = {
    'sgd': torch.optim.SGD, 
    'rmsprop': torch.optim.RMSprop, 
    'adagrad': torch.optim.Adagrad, 
    'adam': torch.optim.Adam, 
    'adamax': torch.optim.Adamax,
    'adadelta': torch.optim.Adadelta,
}

# %%
def train(epoch, model, loss_function, train_loader, optimizer, verbose=False):
    assert loss_function in LOSS_FUNCTIONS
    model.train()
    train_loss = 0
    batch_idx = 0
    for image, _ in train_loader:
        image = image.to(DEVICE)
        
        ## initialize the optimizer
        optimizer.zero_grad()
        
        ## decoded output
        decoded = model(image)
        
        ## compute loss for each batch
        if loss_function == "BCE":
            loss = F.binary_cross_entropy(decoded, image.view(-1, INPUT_SIZE))
        elif loss_function == "MSE":
            loss = F.mse_loss(decoded, image.view(-1, INPUT_SIZE))
        else:
            loss = F.l1_loss(decoded, image.view(-1, INPUT_SIZE))
        
        ## accumulate the total train loss during the epoch and backpropagation
        train_loss += loss.item()
        loss.backward()
        optimizer.step()
        
        ## Check training status
#         if batch_idx % 100 == 0:
#             print(f'Train Epoch: {epoch} [{batch_idx*len(image)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\t Loss: {loss.item()/len(image):.6f}')
        
        batch_idx += 1

    if verbose:
        print(f"Epoch: {epoch} Average training loss: {train_loss / len(train_loader.dataset):.6f}")
    
    return train_loss / len(train_loader.dataset)


def test(epoch, model, loss_function, test_loader, verbose=False):
    model.eval()
    test_loss = 0
    batch_idx = 0
    with torch.no_grad():
        for image, _ in test_loader:
            image = image.to(DEVICE)
            decoded = model(image)

            ## compute loss for each batch
            if loss_function == "BCE":
                loss = F.binary_cross_entropy(decoded, image.view(-1, INPUT_SIZE))
            else:
                loss = F.mse_loss(decoded, image.view(-1, INPUT_SIZE))
            
            test_loss += loss.item()
        
        if verbose:
            print(f"Epoch: {epoch} Average test loss: {test_loss / len(test_loader.dataset):.6f}")
    
    return test_loss / len(test_loader.dataset)

# %%
def run(num_devices, loss_fn, encoded_dim, optim_name, verbose1=False, verbose2=True, save_model=False):
    if num_devices == 1:
        model = AutoEncoder(encoded_dim).to(DEVICE)
    else:
        device_ids = list(np.arange(num_devices))
        model = nn.DataParallel(AutoEncoder(encoded_dim), device_ids=device_ids).to(DEVICE)

    optimizer = OPTIMIZERS[optim_name](model.parameters(), lr=LEARNING_RATE)
#     print(model)
#     print(optimizer)
    
    train_losses = np.zeros(EPOCHS)
    test_losses = np.zeros(EPOCHS)
    for epoch in tqdm(range(EPOCHS)):
        train_loss = train(epoch, model, loss_fn, trainloader, optimizer, verbose=verbose1)
        test_loss = test(epoch, model, loss_fn, testloader, verbose=verbose1)
        
        train_losses[epoch] = train_loss
        test_losses[epoch] = test_loss
        
    if verbose2:
        print(f"{loss_fn}\tEncoded dimension: {encoded_dim}\tAverage Training loss: {np.mean(train_losses):.6f}\tAverage Test loss: {np.mean(test_loss):.6f}")
        
    if save_model:
        saved_model = model.state_dict()
        fname = f"./saved_model_{loss_fn}_{encoded_dim}.pt"
        torch.save(saved_model, fname)
    return np.mean(train_losses), np.mean(test_losses)

# %%
# Loss function, Encoded dimension에 따른 loss 차이
encoded_dims = [4, 16, 64, 144, 256]

bce_train_losses, bce_test_losses = dict(), dict()
for encoded_dim in encoded_dims:
    train_loss, test_loss = run(device_count, "BCE", encoded_dim, "adam", verbose2=True, save_model=False)
    bce_train_losses[encoded_dim] = train_loss
    bce_test_losses[encoded_dim] = test_loss
    
mse_train_losses, mse_test_losses = dict(), dict()
for encoded_dim in encoded_dims:
    train_loss, test_loss = run(device_count, "MSE", encoded_dim, "adam", verbose2=True, save_model=False)
    mse_train_losses[encoded_dim] = train_loss
    mse_test_losses[encoded_dim] = test_loss
    
mae_train_losses, mae_test_losses = dict(), dict()
for encoded_dim in encoded_dims:
    train_loss, test_loss = run(device_count, "MAE", encoded_dim, "adam", verbose2=True, save_model=False)
    mae_train_losses[encoded_dim] = train_loss
    mae_test_losses[encoded_dim] = test_loss
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# BCE	Encoded dimension: 4	Average Training loss: 0.001473	Average Test loss: 0.001350
#   0%|          | 0/20 [00:00<?, ?it/s]
# BCE	Encoded dimension: 16	Average Training loss: 0.001065	Average Test loss: 0.000866
#   0%|          | 0/20 [00:00<?, ?it/s]
# BCE	Encoded dimension: 64	Average Training loss: 0.000881	Average Test loss: 0.000653
#   0%|          | 0/20 [00:00<?, ?it/s]
# BCE	Encoded dimension: 144	Average Training loss: 0.000829	Average Test loss: 0.000615
#   0%|          | 0/20 [00:00<?, ?it/s]
# BCE	Encoded dimension: 256	Average Training loss: 0.000796	Average Test loss: 0.000597
#   0%|          | 0/20 [00:00<?, ?it/s]
# MSE	Encoded dimension: 4	Average Training loss: 0.000333	Average Test loss: 0.000288
#   0%|          | 0/20 [00:00<?, ?it/s]
# MSE	Encoded dimension: 16	Average Training loss: 0.000184	Average Test loss: 0.000124
#   0%|          | 0/20 [00:00<?, ?it/s]
# MSE	Encoded dimension: 64	Average Training loss: 0.000130	Average Test loss: 0.000056
#   0%|          | 0/20 [00:00<?, ?it/s]
# MSE	Encoded dimension: 144	Average Training loss: 0.000111	Average Test loss: 0.000044
#   0%|          | 0/20 [00:00<?, ?it/s]
# MSE	Encoded dimension: 256	Average Training loss: 0.000103	Average Test loss: 0.000038
#   0%|          | 0/20 [00:00<?, ?it/s]
# MAE	Encoded dimension: 4	Average Training loss: 0.000797	Average Test loss: 0.000525
#   0%|          | 0/20 [00:00<?, ?it/s]
# MAE	Encoded dimension: 16	Average Training loss: 0.000603	Average Test loss: 0.000274
#   0%|          | 0/20 [00:00<?, ?it/s]
# MAE	Encoded dimension: 64	Average Training loss: 0.000509	Average Test loss: 0.000183
#   0%|          | 0/20 [00:00<?, ?it/s]
# MAE	Encoded dimension: 144	Average Training loss: 0.000485	Average Test loss: 0.000169
#   0%|          | 0/20 [00:00<?, ?it/s]
# MAE	Encoded dimension: 256	Average Training loss: 0.000481	Average Test loss: 0.000160

# %%
plt.figure(figsize=(16, 4))

plt.subplot(131)
plt.plot(encoded_dims, bce_train_losses.values(), label=f"Training loss", marker='o')
plt.plot(encoded_dims, bce_test_losses.values(), label=f"Test loss", marker='o')
plt.grid(True)
plt.legend()
plt.xlabel("Encoded Dimension")
plt.ylabel("Training/Test Loss")
plt.xticks(encoded_dims)
plt.title("Cross Entropy Loss")

plt.subplot(132)
plt.plot(encoded_dims, mse_train_losses.values(), label=f"Training loss", marker='o')
plt.plot(encoded_dims, mse_test_losses.values(), label=f"Test loss", marker='o')
plt.grid(True)
plt.legend()
plt.xlabel("Encoded Dimension")
plt.ylabel("Training/Test Loss")
plt.xticks(encoded_dims)
plt.title("Mean Squared Error")

plt.subplot(133)
plt.plot(encoded_dims, mae_train_losses.values(), label=f"Training loss", marker='o')
plt.plot(encoded_dims, mae_test_losses.values(), label=f"Test loss", marker='o')
plt.grid(True)
plt.legend()
plt.xlabel("Encoded Dimension")
plt.ylabel("Training/Test Loss")
plt.xticks(encoded_dims)
plt.title("Mean Absolute Error")

plt.tight_layout()
plt.show()

# %%
# Final training
for loss_fn in LOSS_FUNCTIONS:
    train_loss, test_loss = run(device_count, loss_fn, 64, "adam", verbose2=True, save_model=True)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# BCE	Encoded dimension: 64	Average Training loss: 0.000882	Average Test loss: 0.000651
#   0%|          | 0/20 [00:00<?, ?it/s]
# MSE	Encoded dimension: 64	Average Training loss: 0.000129	Average Test loss: 0.000055
#   0%|          | 0/20 [00:00<?, ?it/s]
# MAE	Encoded dimension: 64	Average Training loss: 0.000527	Average Test loss: 0.000184

# %%
## Comparison between the ground truth and re-constructed image
def model_comparison(loss_fn, encoded_dim, indices, dataloader, grid_width, grid_height, figure_width, figure_height, view_encoded=False):
    images, labels = next(iter(dataloader))
    
    ## show ground truth
    print("Ground Truth")
    fig, ax = plt.subplots(grid_height, grid_width)
    fig.set_size_inches(figure_width, figure_height)
    for i in range(grid_height):
        for j in range(grid_width):
            img_idx = indices[i*grid_width + j]
            image, label = images[img_idx], labels[img_idx]
            ax[i][j].axis('off')
            ax[i][j].set_title(label.item(), color='black')
            ax[i][j].imshow(image.squeeze(), cmap='gray')
        plt.subplots_adjust(hspace=0.25)
    plt.tight_layout()
    plt.show()
    
    ## load the trained model
    model = AutoEncoder(encoded_dim)
    checkpoint = torch.load(f'saved_model_{loss_fn}_{encoded_dim}.pt')
    state_dict = OrderedDict()
    for key, value in checkpoint.items():
        key = key.replace('module.', '')
        state_dict[key] = value
    model.load_state_dict(state_dict)
    model.eval()
    
    if view_encoded:
        ## show the encoded images
        print("Encoded")
        fig, ax = plt.subplots(grid_height, grid_width)
        fig.set_size_inches(figure_width, figure_height)
        for i in range(grid_height):
            for j in range(grid_width):
                img_idx = indices[i*grid_width + j]
                image, label = images[img_idx], labels[img_idx]
                encoded = model.encode(image).detach().numpy()

                ax[i][j].axis('off')
                ax[i][j].set_title(label.item(), color='black')
                ax[i][j].imshow(encoded.reshape(8, 8), cmap='gray')
            plt.subplots_adjust(hspace=0.25)
        plt.tight_layout()
        plt.show()        
    
    
    ## show the re-constructed images
    print("Reconstructed")
    fig, ax = plt.subplots(grid_height, grid_width)
    fig.set_size_inches(figure_width, figure_height)
    for i in range(grid_height):
        for j in range(grid_width):
            img_idx = indices[i*grid_width + j]
            image, label = images[img_idx], labels[img_idx]
            decoded = model(image).detach().numpy()

            ax[i][j].axis('off')
            ax[i][j].set_title(label.item(), color='black')
            ax[i][j].imshow(decoded.reshape(28, 28), cmap='gray')
        plt.subplots_adjust(hspace=0.25)
    plt.tight_layout()
    plt.show()

# %%
grid_width, grid_height = 10, 3
figure_width, figure_height = 12, 4
indices = np.random.choice(np.arange(BATCH_SIZE), replace=False, size=grid_height*grid_width)
sampleloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, 
                                           shuffle=False, num_workers=device_count)

for loss_fn in LOSS_FUNCTIONS:
    print(loss_fn)
    model_comparison(loss_fn, 64, indices, sampleloader, grid_width, grid_height, figure_width, figure_height, view_encoded=True)
# Out:
# BCE
# Ground Truth
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 9
#       7 for loss_fn in LOSS_FUNCTIONS:
#       8     print(loss_fn)
# ----> 9     model_comparison(loss_fn, indices, sampleloader, grid_width, grid_height, figure_width, figure_height, view_encoded=True)
#
# Cell In[18], line 27, in model_comparison(loss_fn, indices, dataloader, grid_width, grid_height, figure_width, figure_height, view_encoded)
#      25     key = key.replace('module.', '')
#      26     state_dict[key] = value
# ---> 27 model.load_state_dict(state_dict)
#      28 model.eval()
#      30 if view_encoded:
#      31     ## show the encoded images
#
# File ~/anaconda3/envs/main/lib/python3.10/site-packages/torch/nn/modules/module.py:1667, in Module.load_state_dict(self, state_dict, strict)
#    1662         error_msgs.insert(
#    1663             0, 'Missing key(s) in state_dict: {}. '.format(
#    1664                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1666 if len(error_msgs) > 0:
# -> 1667     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1668                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1669 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for AutoEncoder:
# 	size mismatch for fc1.weight: copying a param with shape torch.Size([1024, 784]) from checkpoint, the shape in current model is torch.Size([512, 784]).
# 	size mismatch for fc1.bias: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for fc2.weight: copying a param with shape torch.Size([256, 1024]) from checkpoint, the shape in current model is torch.Size([64, 512]).
# 	size mismatch for fc2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for fc3.weight: copying a param with shape torch.Size([1024, 256]) from checkpoint, the shape in current model is torch.Size([512, 64]).
# 	size mismatch for fc3.bias: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for fc4.weight: copying a param with shape torch.Size([784, 1024]) from checkpoint, the shape in current model is torch.Size([784, 512]).
