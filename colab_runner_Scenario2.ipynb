# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/Colab Notebooks/Bandits/RoLF/bandit-research/rolf
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Bandits/RoLF/bandit-research/rolf

# %%
# !ls
# Out:
# calculate_alpha.py	      figures	     __pycache__       scripts_case2
# cfg.py			      get_primes.py  RoLFLasso.ipynb   test.py
# colab_runner.ipynb	      logs	     run_scenario2.sh  util.py
# colab_runner_Scenario2.ipynb  main.py	     run.sh
# experiment.ipynb	      models.py      scripts_case1

# %%
# !bash run_scenario2.sh
# Out:
# case : 1, SEED : 103, K : 30, Latent_dim : 60, Obs_dim : 60, Trial : 0, p : 0.6, Agent : DRLassoBandit, Round : 1, optimal : 26, chosen : 9
# case : 1, SEED : 103, K : 30, Latent_dim : 60, Obs_dim : 60, Trial : 0, p : 0.6, Agent : UCBDelta, Round : 1, optimal : 26, chosen : 25
# case : 1, SEED : 103, K : 30, Latent_dim : 60, Obs_dim : 60, Trial : 0, p : 0.6, Agent : RoLFRidge, Round : 1, optimal : 26, a_hat: 25, pseudo : 23, chosen : 23
# case : 1, SEED : 103, K : 30, Latent_dim : 60, Obs_dim : 60, Trial : 0, p : 0.6, Agent : LinUCB, Round : 1, optimal : 26, chosen : 25
# case : 1, SEED : 103, K : 30, Latent_dim : 60, Obs_dim : 60, Trial : 0, p : 0.6, Agent : RoLFLasso, Round : 1, optimal : 26, a_hat: 25, pseudo : 23, chosen : 23
# case : 1, SEED : 103, K : 30, Latent_dim : 60, Obs_dim : 60, Trial : 0, p : 0.6, Agent : LinTS, Round : 1, optimal : 26, chosen : 6
# ...
