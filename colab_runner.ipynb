# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/Colab Notebooks/Bandits/RoLF/bandit-research/rolf
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Bandits/RoLF/bandit-research/rolf

# %%
# !ls
# Out:
# calculate_alpha.py  experiment.ipynb  main.py	       run.sh	      test.py
# cfg.py		    figures	      models.py        scripts_case1  util.py
# colab_runner.ipynb  get_primes.py     RoLFLasso.ipynb  scripts_case2

# %%
# !touch run_scenario2.sh

# %%
# !bash run.sh
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# case : 1, SEED : 103, K : 30, Latent_dim : 35, Obs_dim : 17, Trial : 2, p : 0.6, Agent : UCBDelta, Round : 623, optimal : 23, chosen : 22
# case : 1, SEED : 103, K : 30, Latent_dim : 35, Obs_dim : 17, Trial : 2, p : 0.6, Agent : LinUCB, Round : 490, optimal : 23, chosen : 20
# case : 1, SEED : 103, K : 30, Latent_dim : 35, Obs_dim : 17, Trial : 2, p : 0.6, Agent : LinTS, Round : 401, optimal : 23, chosen : 1
# case : 1, SEED : 103, K : 30, Latent_dim : 35, Obs_dim : 17, Trial : 2, p : 0.6, Agent : UCBDelta, Round : 624, optimal : 23, chosen : 22
# case : 1, SEED : 103, K : 30, Latent_dim : 35, Obs_dim : 17, Trial : 2, p : 0.6, Agent : LinUCB, Round : 491, optimal : 23, chosen : 1
# case : 1, SEED : 103, K : 30, Latent_dim : 35, Obs_dim : 17, Trial : 2, p : 0.6, Agent : LinTS, Round : 402, optimal : 23, chosen : 5
# ...
